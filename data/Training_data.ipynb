# %%
import pandas as pd

# %%
df08 = pd.read_excel(r"Raw Data 10yrs_v3.xlsx", sheet_name="2008")
df09 = pd.read_excel(r"Raw Data 10yrs_v3.xlsx", sheet_name="2009")
df10 = pd.read_excel(r"Raw Data 10yrs_v3.xlsx", sheet_name="2010")
df11 = pd.read_excel(r"Raw Data 10yrs_v3.xlsx", sheet_name="2011")
df12 = pd.read_excel(r"Raw Data 10yrs_v3.xlsx", sheet_name="2012")
df13 = pd.read_excel(r"Raw Data 10yrs_v3.xlsx", sheet_name="2013")
df14 = pd.read_excel(r"Raw Data 10yrs_v3.xlsx", sheet_name="2014")
df15 = pd.read_excel(r"Raw Data 10yrs_v3.xlsx", sheet_name="2015")
df16 = pd.read_excel(r"Raw Data 10yrs_v3.xlsx", sheet_name="2016")
df17 = pd.read_excel(r"Raw Data 10yrs_v3.xlsx", sheet_name="2017")
df18 = pd.read_excel(r"Raw Data 10yrs_v3.xlsx", sheet_name="2018")

df = [df08,df09,df10,df11,df12,df13,df14,df15,df16,df17,df18]

# %%
# Rename columns

for i in range(11):
    currDf = df[i]
    currDf.rename(columns={"Unnamed: 0": "Name", "Unnamed: 1": "Team", "Unnamed: 2": "Pos", "Unnamed: 3": "Age", "Games": "G", "Games.1": "GS", "Passing": "P_Cmp", "Passing.1": "P_Att", "Passing.2": "P_Yds", "Passing.3": "P_TD", "Passing.4": "P_Int", "Rushing": "Ru_Att", "Rushing.1": "Ru_Yds", "Rushing.2": "Y/A", "Rushing.3": "R_TD", "Receiving": "Tgt", "Receiving.1": "Rec", "Receiving.2": "Re_Yds", "Receiving.3": "Y/R", "Receiving.4": "Re_TD", "Fantasy": "Total_Pts", "Fantasy.1": "PPR", "Fantasy.2": "PosRank"}, inplace=True)
    df[i] = currDf.drop(currDf.index[0])
    
df[0]
# Out:
#                   Name Team  Pos Age   G  GS P_Cmp P_Att P_Yds P_TD  ...  \
# 1           Drew Brees  NOR   QB  29  16  16   413   635  5069   34  ...
# 2        Aaron Rodgers  GNB   QB  25  16  16   341   536  4038   28  ...
# 3        Philip Rivers  SDG   QB  27  16  16   312   478  4009   34  ...
# 4    DeAngelo Williams  CAR   RB  25  16  16     0     0     0    0  ...
# 5           Jay Cutler  DEN   QB  25  16  16   384   616  4526   25  ...
# ..                 ...  ...  ...  ..  ..  ..   ...   ...   ...  ...  ...
# 574      George Wilson  BUF  NaN  27  16   3     0     0     0    0  ...
# 575        Kris Wilson  SDG  NaN  27   3   0     0     0     0    0  ...
# 576       D'Juan Woods  JAX  NaN  24   1   0     0     0     0    0  ...
# 577     Wallace Wright  NYJ  NaN  24  16   0     0     0     0    0  ...
# 578        Joe Zelenka  JAX  NaN  32  16   0     0     0     0    0  ...
#
#       Y/A R_TD  Tgt Rec Re_Yds  Y/R Re_TD Total_Pts  PPR PosRank
# 1   -0.05    0    0   0      0  NaN     0       305  305       1
# 2     3.7    4    0   0      0  NaN     0       296  296       2
# 3    2.71    0    0   0      0  NaN     0       287  287       3
# 4    5.55   18   30  22    121  5.5     2       286  308       1
# 5    3.51    2    0   0      0  NaN     0       281  281       4
# ..    ...  ...  ...  ..    ...  ...   ...       ...  ...     ...
# 574   NaN    0    0   0      0  NaN     0       NaN  NaN     184
# 575   NaN    0  NaN   0      0  NaN     0       NaN  NaN     106
# 576   NaN    0  NaN   0      0  NaN     0       NaN  NaN     205
# 577   NaN    0    0   0      0  NaN     0       NaN  NaN     191
# 578   NaN    0  NaN   0      0  NaN     0       NaN  NaN     102
#
# [578 rows x 23 columns]

# %%
# possibly remove players with no position
# should we remove players who have no stats next season?

# %%
# add column of next season to current season

# for i in range(10):
#     currDf = df[i]
#     nextDf = df[i+1][["Name", "Total_Pts"]]
#     currDf.join(nextDf, )
    
# df[0]
# Out:
#                   Name Team  Pos Age   G  GS P_Cmp P_Att P_Yds P_TD  ... R_TD  \
# 1           Drew Brees  NOR   QB  29  16  16   413   635  5069   34  ...    0
# 2        Aaron Rodgers  GNB   QB  25  16  16   341   536  4038   28  ...    4
# 3        Philip Rivers  SDG   QB  27  16  16   312   478  4009   34  ...    0
# 4    DeAngelo Williams  CAR   RB  25  16  16     0     0     0    0  ...   18
# 5           Jay Cutler  DEN   QB  25  16  16   384   616  4526   25  ...    2
# ..                 ...  ...  ...  ..  ..  ..   ...   ...   ...  ...  ...  ...
# 574      George Wilson  BUF  NaN  27  16   3     0     0     0    0  ...    0
# 575        Kris Wilson  SDG  NaN  27   3   0     0     0     0    0  ...    0
# 576       D'Juan Woods  JAX  NaN  24   1   0     0     0     0    0  ...    0
# 577     Wallace Wright  NYJ  NaN  24  16   0     0     0     0    0  ...    0
# 578        Joe Zelenka  JAX  NaN  32  16   0     0     0     0    0  ...    0
#
#      Tgt Rec Re_Yds  Y/R Re_TD Total_Pts  PPR PosRank Next_Season_Pts
# 1      0   0      0  NaN     0       305  305       1             351
# 2      0   0      0  NaN     0       296  296       2             349
# 3      0   0      0  NaN     0       287  287       3             306
# 4     30  22    121  5.5     2       286  308       1             290
# 5      0   0      0  NaN     0       281  281       4             287
# ..   ...  ..    ...  ...   ...       ...  ...     ...             ...
# 574    0   0      0  NaN     0       NaN  NaN     184             NaN
# 575  NaN   0      0  NaN     0       NaN  NaN     106             NaN
# 576  NaN   0      0  NaN     0       NaN  NaN     205             NaN
# 577    0   0      0  NaN     0       NaN  NaN     191             NaN
# 578  NaN   0      0  NaN     0       NaN  NaN     102             NaN
#
# [578 rows x 24 columns]
